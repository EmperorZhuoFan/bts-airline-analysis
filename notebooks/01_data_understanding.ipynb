# %% [markdown]
# # Data Understanding
#
# ## Purpose
#
# This notebook investigates the structure, quality, and characteristics of the raw BTS airline dataset before data preparation and analysis.
#
# ## Objectives
#
# * Understand the dataset structure and dimensions.
# * Inspect the available variables and their data types.
# * Identify missing values and duplicate records.
# * Examine basic statistical characteristics.
# * Establish an initial understanding of the dataset before downstream analysis.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/AIRLINE_BTS.csv")

# %% [markdown]
# ## 3. Dataset Dimensions
#
# First, inspect the number of observations and variables contained in the raw dataset.

# %%
df.shape
# Out:
# (675500, 34)

# %% [markdown]
# ## 4. Column Inspection
#
# Inspect the available variables to understand the information contained in each flight record.

# %%
df.columns.tolist()
# Out:
# ['YEAR',
#  'QUARTER',
#  'MONTH',
#  'DAY_OF_WEEK',
#  'FL_DATE',
#  'OP_UNIQUE_CARRIER',
#  'TAIL_NUM',
#  'ORIGIN',
#  'ORIGIN_CITY_NAME',
#  'ORIGIN_STATE_ABR',
#  'DEST',
#  'DEST_CITY_NAME',
#  'DEST_STATE_ABR',
#  'CRS_DEP_TIME',
#  'DEP_TIME',
#  'DEP_DELAY',
#  'DEP_DELAY_NEW',
#  'TAXI_OUT',
#  'TAXI_IN',
#  'CRS_ARR_TIME',
#  'ARR_TIME',
#  'ARR_DELAY',
#  'ARR_DELAY_NEW',
#  'ARR_DEL15',
#  'CANCELLED',
#  'CANCELLATION_CODE',
#  'DIVERTED',
#  'ACTUAL_ELAPSED_TIME',
#  'AIR_TIME',
#  'DISTANCE',
#  'CARRIER_DELAY',
#  'NAS_DELAY',
#  'SECURITY_DELAY',
#  'LATE_AIRCRAFT_DELAY']

# %% [markdown]
# ## 5. Data Types
#
# Inspect the data types of the available variables to identify numerical, categorical, and temporal fields.

# %%
df.dtypes
# Out:
# YEAR                     int64
# QUARTER                  int64
# MONTH                    int64
# DAY_OF_WEEK              int64
# FL_DATE                 object
# OP_UNIQUE_CARRIER       object
# TAIL_NUM                object
# ORIGIN                  object
# ORIGIN_CITY_NAME        object
# ORIGIN_STATE_ABR        object
# DEST                    object
# DEST_CITY_NAME          object
# DEST_STATE_ABR          object
# CRS_DEP_TIME             int64
# DEP_TIME               float64
# DEP_DELAY              float64
# DEP_DELAY_NEW          float64
# TAXI_OUT               float64
# TAXI_IN                float64
# CRS_ARR_TIME             int64
# ARR_TIME               float64
# ARR_DELAY              float64
# ARR_DELAY_NEW          float64
# ARR_DEL15              float64
# CANCELLED              float64
# CANCELLATION_CODE       object
# DIVERTED               float64
# ACTUAL_ELAPSED_TIME    float64
# AIR_TIME               float64
# DISTANCE               float64
# ...

# %% [markdown]
# ## 6. Missing Values
#
# Examine the number of missing values in each variable to identify fields requiring attention during data preparation.

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CANCELLATION_CODE      655615
# LATE_AIRCRAFT_DELAY    517744
# CARRIER_DELAY          517744
# SECURITY_DELAY         517744
# NAS_DELAY              517744
# AIR_TIME                22210
# ACTUAL_ELAPSED_TIME     22210
# ARR_DEL15               22202
# ARR_DELAY_NEW           22202
# ARR_DELAY               22202
# TAXI_IN                 20150
# ARR_TIME                20150
# TAXI_OUT                19787
# DEP_DELAY               19206
# DEP_DELAY_NEW           19206
# DEP_TIME                19106
# TAIL_NUM                 2926
# YEAR                        0
# QUARTER                     0
# DEST                        0
# DEST_STATE_ABR              0
# DEST_CITY_NAME              0
# OP_UNIQUE_CARRIER           0
# ORIGIN                      0
# ORIGIN_CITY_NAME            0
# ORIGIN_STATE_ABR            0
# DAY_OF_WEEK                 0
# FL_DATE                     0
# MONTH                       0
# CRS_DEP_TIME                0
# CANCELLED                   0
# ...

# %% [markdown]
# ## 7. Duplicate Records
#
# Check whether the raw dataset contains duplicate flight records before data preparation.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 8. Basic Statistical Summary
#
# Review descriptive statistics for the numerical variables to understand their distributions and identify potential anomalies.

# %%
df.describe()
# Out:
#            YEAR   QUARTER     MONTH    DAY_OF_WEEK   CRS_DEP_TIME  \
# count  675500.0  675500.0  675500.0  675500.000000  675500.000000
# mean     2026.0       1.0       3.0       3.945612    1331.437283
# std         0.0       0.0       0.0       2.085423     496.217863
# min      2026.0       1.0       3.0       1.000000       5.000000
# 25%      2026.0       1.0       3.0       2.000000     906.000000
# 50%      2026.0       1.0       3.0       4.000000    1325.000000
# 75%      2026.0       1.0       3.0       6.000000    1743.000000
# max      2026.0       1.0       3.0       7.000000    2359.000000
#
#             DEP_TIME      DEP_DELAY  DEP_DELAY_NEW       TAXI_OUT  \
# count  656394.000000  656294.000000  656294.000000  655713.000000
# mean     1338.527822      17.074045      20.516724      18.834249
# std       515.973885      65.735290      64.526236      10.750599
# min         1.000000     -56.000000       0.000000       1.000000
# ...

# %% [markdown]
# ## 9. Initial Observations
#
# Summarize the main characteristics and potential data-quality considerations identified during the initial inspection of the raw dataset.

# %%
print(f"Dataset contains {df.shape[0]:,} flight records and {df.shape[1]} variables.")
print(f"Total missing values: {df.isnull().sum().sum():,}")
print(f"Duplicate records: {df.duplicated().sum():,}")
# Out:
# Dataset contains 675,500 flight records and 34 variables.
# Total missing values: 2,958,148
# Duplicate records: 0
